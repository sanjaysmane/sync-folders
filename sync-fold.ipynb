# %% [markdown]
# # Sync of 2 Folders

# %%
import sys
import os
import shutil
import logging
import logging.config
import schedule
import time


# logging logs to sync.log file
def loggerFunc(fname):
    logging_config = { 
        'version': 1,
        'formatters': { 
            'standard': { 
                'format': '%(asctime)s - %(levelname)s - %(message)s'
            },
        },
        'handlers': { 
            'stream': { 
                'level': 'INFO',
                'formatter': 'standard',
                'class': 'logging.StreamHandler',
            },
            'file': { 
                'level': 'INFO',
                'formatter': 'standard',
                'class': 'logging.FileHandler',
                'filename': fname
            },
        },
        'loggers': { 
            __name__: { 
                'handlers': ['stream', 'file'],
                'level': 'INFO',
                'propagate': False
            },
        } 
    }
    logging.config.dictConfig(logging_config)
    logger = logging.getLogger(__name__)
    return logger

def copy_files(path_src, path_dest, logger):
    #this loop will go through every folder and file to copy
    for folderName, subfolders, fileNames in os.walk(path_src):
        for subfolder in subfolders:
            try:
                new_path = folderName.replace(path_src, path_dest) 
                logger.info('created folder at destination: ' + subfolder)
                os.mkdir(new_path+'\\'+subfolder)
            except:
                logger.warning("folder exists: " + subfolder)
        for fileName in fileNames:
            new_path = folderName.replace(path_src, path_dest)
            file = folderName + '\\'+ fileName
            shutil.copy(file, new_path)
            logger.info(file + ' is copied to: ' + new_path)
    logger.info('All files and folders from source copied to destination')    

def sync_files(path_src, path_dest, logger):
    for filename in os.listdir(path_dest):
        try:
            filename_s=path_src + os.sep + filename
            filename_t=path_dest + os.sep + filename
            if not os.path.exists(filename_s):   
                if os.path.isdir(filename_t):
                    logger.info('This folder do not exist in source so removed: '+ filename_t)
                    shutil.rmtree(filename_t)
                else:
                    logger.info('This file do not exist in source so removed: '+ filename_t)
                    os.remove(filename_t)      
        except:
                logger.error("something went wrong while removing files")
    
    for folderName, subfolders, fileNames in os.walk(path_dest):
        for subfolder in subfolders:
            try:
                new_path_src = folderName.replace(path_dest, path_src) 
                folderNameSrc = new_path_src+'\\'+subfolder
                new_path_dest = folderName.replace(path_src, path_dest)
                folderNameDest = new_path_dest+'\\'+subfolder
                if not os.path.exists(folderNameSrc):
                    logger.info('this folder does not exist in source, so removing' + folderNameDest)
                    shutil.rmtree(folderNameDest)
                else:
                    for filename in os.listdir(folderNameDest):
                        fileToCheck = folderNameSrc+'\\'+filename
                        fileToRemove = folderNameDest+'\\'+filename
                        if not os.path.exists(fileToCheck):
                            logger.info('this file in subfolder does not exist in source, so removing' + folderNameDest)
                            os.remove(fileToRemove)
            except:
                logger.error("something went wrong while removing file or folder")
    logger.info('all files and folders from destination are matched and updated as per source folder')

    
def sync_folders(source, dest, logfilename):
    copy_files(source, dest, logger =loggerFunc(logfilename))
    sync_files(source, dest, logger =loggerFunc(logfilename))
    

def syncOnTimeInterval(source, dest, logfilename, mins):
    # runs sync_folders function at given time interval in minutes
    schedule.every(mins).minutes.do(lambda : sync_folders(source, dest, logfilename))
    while True:
        schedule.run_pending()
        time.sleep(300)

# %%
source = 'C:\\Users\sanju\Documents\sync-folders-project\Source_folder'
dest = 'C:\\Users\sanju\Documents\sync-folders-project\Replica_folder'

syncOnTimeInterval(source, dest, 'loggerNew.txt', 1)
# Out:
# 2022-10-16 10:22:36,774 - INFO - created folder at destination: stories for arshan
# 2022-10-16 10:22:36,782 - WARNING - folder exists: stories for arshan
# 2022-10-16 10:22:36,782 - INFO - created folder at destination: test
# 2022-10-16 10:22:36,790 - WARNING - folder exists: test
# 2022-10-16 10:22:36,790 - INFO - C:\Users\sanju\Documents\sync-folders-project\Source_folder\Anschreiben-copy.docx is copied to: C:\Users\sanju\Documents\sync-folders-project\Replica_folder
# 2022-10-16 10:22:36,798 - INFO - C:\Users\sanju\Documents\sync-folders-project\Source_folder\cars-bad-buy.ipynb is copied to: C:\Users\sanju\Documents\sync-folders-project\Replica_folder
# 2022-10-16 10:22:36,803 - INFO - C:\Users\sanju\Documents\sync-folders-project\Source_folder\froinloop.py is copied to: C:\Users\sanju\Documents\sync-folders-project\Replica_folder
# 2022-10-16 10:22:36,810 - INFO - C:\Users\sanju\Documents\sync-folders-project\Source_folder\interview answer.docx is copied to: C:\Users\sanju\Documents\sync-folders-project\Replica_folder
# 2022-10-16 10:22:36,846 - INFO - C:\Users\sanju\Documents\sync-folders-project\Source_folder\Nested_json_dict_addingto couln_for_loop.pdf is copied to: C:\Users\sanju\Documents\sync-folders-project\Replica_folder
# 2022-10-16 10:22:36,870 - INFO - C:\Users\sanju\Documents\sync-folders-project\Source_folder\stories for arshan\023-A-DOG-ON-A-LOG-Free-Childrens-Book-By-Monkey-Pen.pdf is copied to: C:\Users\sanju\Documents\sync-folders-project\Replica_folder\stories for arshan
# 2022-10-16 10:22:36,894 - INFO - C:\Users\sanju\Documents\sync-folders-project\Source_folder\stories for arshan\certificates-B2 Degree,ZAB.pdf is copied to: C:\Users\sanju\Documents\sync-folders-project\Replica_folder\stories for arshan
# 2022-10-16 10:22:36,918 - INFO - C:\Users\sanju\Documents\sync-folders-project\Source_folder\stories for arshan\Test_Gesamtfragenkatalog_BAMF.pdf is copied to: C:\Users\sanju\Documents\sync-folders-project\Replica_folder\stories for arshan
# 2022-10-16 10:22:36,926 - INFO - C:\Users\sanju\Documents\sync-folders-project\Source_folder\stories for arshan\Test_Lernkarten_Leben_in_Deutschland.pdf is copied to: C:\Users\sanju\Documents\sync-folders-project\Replica_folder\stories for arshan
# 2022-10-16 10:22:36,926 - INFO - C:\Users\sanju\Documents\sync-folders-project\Source_folder\test\Anschreiben-copy.docx is copied to: C:\Users\sanju\Documents\sync-folders-project\Replica_folder\test
# 2022-10-16 10:22:36,934 - INFO - All files and folders from source copied to destination
# 2022-10-16 10:22:36,942 - INFO - all files and folders from destination are matched and updated as per source folder
# 2022-10-16 10:22:36,942 - INFO - created folder at destination: stories for arshan
# 2022-10-16 10:22:36,950 - WARNING - folder exists: stories for arshan
# 2022-10-16 10:22:36,953 - INFO - created folder at destination: test
# 2022-10-16 10:22:36,953 - WARNING - folder exists: test
# 2022-10-16 10:22:36,960 - INFO - C:\Users\sanju\Documents\sync-folders-project\Source_folder\Anschreiben-copy.docx is copied to: C:\Users\sanju\Documents\sync-folders-project\Replica_folder
# 2022-10-16 10:22:36,971 - INFO - C:\Users\sanju\Documents\sync-folders-project\Source_folder\cars-bad-buy.ipynb is copied to: C:\Users\sanju\Documents\sync-folders-project\Replica_folder
# 2022-10-16 10:22:36,977 - INFO - C:\Users\sanju\Documents\sync-folders-project\Source_folder\froinloop.py is copied to: C:\Users\sanju\Documents\sync-folders-project\Replica_folder
# 2022-10-16 10:22:36,985 - INFO - C:\Users\sanju\Documents\sync-folders-project\Source_folder\interview answer.docx is copied to: C:\Users\sanju\Documents\sync-folders-project\Replica_folder
# 2022-10-16 10:22:37,017 - INFO - C:\Users\sanju\Documents\sync-folders-project\Source_folder\Nested_json_dict_addingto couln_for_loop.pdf is copied to: C:\Users\sanju\Documents\sync-folders-project\Replica_folder
# 2022-10-16 10:22:37,035 - INFO - C:\Users\sanju\Documents\sync-folders-project\Source_folder\stories for arshan\023-A-DOG-ON-A-LOG-Free-Childrens-Book-By-Monkey-Pen.pdf is copied to: C:\Users\sanju\Documents\sync-folders-project\Replica_folder\stories for arshan
# 2022-10-16 10:22:37,043 - INFO - C:\Users\sanju\Documents\sync-folders-project\Source_folder\stories for arshan\certificates-B2 Degree,ZAB.pdf is copied to: C:\Users\sanju\Documents\sync-folders-project\Replica_folder\stories for arshan
# 2022-10-16 10:22:37,060 - INFO - C:\Users\sanju\Documents\sync-folders-project\Source_folder\stories for arshan\Test_Gesamtfragenkatalog_BAMF.pdf is copied to: C:\Users\sanju\Documents\sync-folders-project\Replica_folder\stories for arshan
# 2022-10-16 10:22:37,068 - INFO - C:\Users\sanju\Documents\sync-folders-project\Source_folder\stories for arshan\Test_Lernkarten_Leben_in_Deutschland.pdf is copied to: C:\Users\sanju\Documents\sync-folders-project\Replica_folder\stories for arshan
# 2022-10-16 10:22:37,077 - INFO - C:\Users\sanju\Documents\sync-folders-project\Source_folder\test\Anschreiben-copy.docx is copied to: C:\Users\sanju\Documents\sync-folders-project\Replica_folder\test
# 2022-10-16 10:22:37,077 - INFO - All files and folders from source copied to destination
# 2022-10-16 10:22:37,085 - INFO - all files and folders from destination are matched and updated as per source folder
# 2022-10-16 10:22:37,093 - INFO - created folder at destination: stories for arshan
# 2022-10-16 10:22:37,093 - WARNING - folder exists: stories for arshan
# 2022-10-16 10:22:37,104 - INFO - created folder at destination: test
# 2022-10-16 10:22:37,110 - WARNING - folder exists: test
# 2022-10-16 10:22:37,110 - INFO - C:\Users\sanju\Documents\sync-folders-project\Source_folder\Anschreiben-copy.docx is copied to: C:\Users\sanju\Documents\sync-folders-project\Replica_folder
# 2022-10-16 10:22:37,118 - INFO - C:\Users\sanju\Documents\sync-folders-project\Source_folder\cars-bad-buy.ipynb is copied to: C:\Users\sanju\Documents\sync-folders-project\Replica_folder
# 2022-10-16 10:22:37,126 - INFO - C:\Users\sanju\Documents\sync-folders-project\Source_folder\froinloop.py is copied to: C:\Users\sanju\Documents\sync-folders-project\Replica_folder
# 2022-10-16 10:22:37,134 - INFO - C:\Users\sanju\Documents\sync-folders-project\Source_folder\interview answer.docx is copied to: C:\Users\sanju\Documents\sync-folders-project\Replica_folder
# 2022-10-16 10:22:37,160 - INFO - C:\Users\sanju\Documents\sync-folders-project\Source_folder\Nested_json_dict_addingto couln_for_loop.pdf is copied to: C:\Users\sanju\Documents\sync-folders-project\Replica_folder
# 2022-10-16 10:22:37,185 - INFO - C:\Users\sanju\Documents\sync-folders-project\Source_folder\stories for arshan\023-A-DOG-ON-A-LOG-Free-Childrens-Book-By-Monkey-Pen.pdf is copied to: C:\Users\sanju\Documents\sync-folders-project\Replica_folder\stories for arshan
# 2022-10-16 10:22:37,201 - INFO - C:\Users\sanju\Documents\sync-folders-project\Source_folder\stories for arshan\certificates-B2 Degree,ZAB.pdf is copied to: C:\Users\sanju\Documents\sync-folders-project\Replica_folder\stories for arshan
# 2022-10-16 10:22:37,209 - INFO - C:\Users\sanju\Documents\sync-folders-project\Source_folder\stories for arshan\Test_Gesamtfragenkatalog_BAMF.pdf is copied to: C:\Users\sanju\Documents\sync-folders-project\Replica_folder\stories for arshan
# 2022-10-16 10:22:37,217 - INFO - C:\Users\sanju\Documents\sync-folders-project\Source_folder\stories for arshan\Test_Lernkarten_Leben_in_Deutschland.pdf is copied to: C:\Users\sanju\Documents\sync-folders-project\Replica_folder\stories for arshan
# 2022-10-16 10:22:37,231 - INFO - C:\Users\sanju\Documents\sync-folders-project\Source_folder\test\Anschreiben-copy.docx is copied to: C:\Users\sanju\Documents\sync-folders-project\Replica_folder\test
# 2022-10-16 10:22:37,231 - INFO - All files and folders from source copied to destination
# 2022-10-16 10:22:37,244 - INFO - all files and folders from destination are matched and updated as per source folder
# 2022-10-16 10:22:37,248 - INFO - created folder at destination: stories for arshan
# 2022-10-16 10:22:37,248 - WARNING - folder exists: stories for arshan
# 2022-10-16 10:22:37,248 - INFO - created folder at destination: test
# 2022-10-16 10:22:37,248 - WARNING - folder exists: test
# 2022-10-16 10:22:37,260 - INFO - C:\Users\sanju\Documents\sync-folders-project\Source_folder\Anschreiben-copy.docx is copied to: C:\Users\sanju\Documents\sync-folders-project\Replica_folder
# 2022-10-16 10:22:37,268 - INFO - C:\Users\sanju\Documents\sync-folders-project\Source_folder\cars-bad-buy.ipynb is copied to: C:\Users\sanju\Documents\sync-folders-project\Replica_folder
# 2022-10-16 10:22:37,268 - INFO - C:\Users\sanju\Documents\sync-folders-project\Source_folder\froinloop.py is copied to: C:\Users\sanju\Documents\sync-folders-project\Replica_folder
# 2022-10-16 10:22:37,276 - INFO - C:\Users\sanju\Documents\sync-folders-project\Source_folder\interview answer.docx is copied to: C:\Users\sanju\Documents\sync-folders-project\Replica_folder
# 2022-10-16 10:22:37,304 - INFO - C:\Users\sanju\Documents\sync-folders-project\Source_folder\Nested_json_dict_addingto couln_for_loop.pdf is copied to: C:\Users\sanju\Documents\sync-folders-project\Replica_folder
# 2022-10-16 10:22:37,316 - INFO - C:\Users\sanju\Documents\sync-folders-project\Source_folder\stories for arshan\023-A-DOG-ON-A-LOG-Free-Childrens-Book-By-Monkey-Pen.pdf is copied to: C:\Users\sanju\Documents\sync-folders-project\Replica_folder\stories for arshan
# 2022-10-16 10:22:37,335 - INFO - C:\Users\sanju\Documents\sync-folders-project\Source_folder\stories for arshan\certificates-B2 Degree,ZAB.pdf is copied to: C:\Users\sanju\Documents\sync-folders-project\Replica_folder\stories for arshan
# 2022-10-16 10:22:37,346 - INFO - C:\Users\sanju\Documents\sync-folders-project\Source_folder\stories for arshan\Test_Gesamtfragenkatalog_BAMF.pdf is copied to: C:\Users\sanju\Documents\sync-folders-project\Replica_folder\stories for arshan
# 2022-10-16 10:22:37,346 - INFO - C:\Users\sanju\Documents\sync-folders-project\Source_folder\stories for arshan\Test_Lernkarten_Leben_in_Deutschland.pdf is copied to: C:\Users\sanju\Documents\sync-folders-project\Replica_folder\stories for arshan
# 2022-10-16 10:22:37,360 - INFO - C:\Users\sanju\Documents\sync-folders-project\Source_folder\test\Anschreiben-copy.docx is copied to: C:\Users\sanju\Documents\sync-folders-project\Replica_folder\test
# 2022-10-16 10:22:37,364 - INFO - All files and folders from source copied to destination
# 2022-10-16 10:22:37,377 - INFO - all files and folders from destination are matched and updated as per source folder
